# %%
import pandas as pd

pd.load
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       3 pd.load
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import dill


with open('pipeline_1.pkl', 'rb') as file:
    # Load the object
    data = dill.load(file)
    print(data)


bruh = data()
# Out:
# <function pipe1 at 0x7fc090daea30>
